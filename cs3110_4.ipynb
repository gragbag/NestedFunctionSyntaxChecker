# %% [markdown]
# <a href="https://colab.research.google.com/github/gragbag/NestedFunctionSyntaxChecker/blob/main/cs3110_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

class PDA:
  def __init__(self):
    self.stack = ['Z']
    self.state = 'q0'
    self.path = []
    self.terminals = {'int', 'float', 'void', '=', ',', '+', '*', '{', '}', '(', ')', ';', 'return'}
    self.transitions = {
        ('q0', None, 'Z'): [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')],

        #q1 FuncDecl
        ('q1', None, 'FuncDecl'): [('q1', 'ReturnType FunctionName ( ParamList ) Block')],

        #q1 ReturnType
        ('q1', 'int', 'ReturnType'): [('q1', None)],
        ('q1', 'float', 'ReturnType'): [('q1', None)],
        ('q1', 'void', 'ReturnType'): [('q1', None)],

        #q2 Type
        ('q2', 'int', 'Type'): [('q7', None)],
        ('q2', 'float', 'Type'): [('q7', None)],

        #q3 ParamList
        ('q1', 'var', 'FunctionName'): [('q3', None)],

        ('q3', '(', '('): [('q3', None)],
        ('q3', ')', ')'): [('q3', None)],
        ('q3', None, 'ParamList'): [('q4', 'Param'), ('q4', 'Param , ParamList')],
        ('q3', ',', ','): [('q3', None)],

        #q4 Params
        ('q4', 'int', 'Param'): [('q3', 'var')],
        ('q4', 'float', 'Param'): [('q3', 'var')],
        ('q3', 'var', 'var'): [('q3', None)],

        #q3 Block, q5 StatementList
        ('q3', '{', 'Block'): [('q5', 'StmtList }')],

        ('q5', None, 'StmtList'): [('q6', 'Stmt ;'), ('q6', 'Stmt ; StmtList')],
        ('q5', '}', '}'): [('q0', None)], #When the function declaration ends, go back to q0
        ('q6', ';', ';'): [('q5', None)],
        ('q6', ';', 'Z'): [('q0', 'Z')], #When the assignment finishes, go back to z0
        ('q6', ')', ')'): [('q6', None)],
        ('q6', '+', 'Operator'): [('q9', 'Expr')],
        ('q6', '*', 'Operator'): [('q9', 'Expr')],

        #q6 statements
        ('q6', None, 'Stmt'): [('q7', 'Assign'), ('q8', 'Return')],

        #q7 assign
        ('q7', 'var', 'Assign'): [('q9', '= Expr')],

        #q9 Expr and Operator
        ('q9', '=', '='): [('q9', None)],

        ('q9', 'var', 'Expr'): [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')],
        ('q9', 'num', 'Expr'): [('q6', None), ('q9', 'Operator')],
        ('q9', ';', ';'): [('q5', None)],
        ('q9', ',', ','): [('q13', None)],

        ('q9', '+', 'Operator'): [('q9', 'Expr')],
        ('q9', '*', 'Operator'): [('q9', 'Expr')],

        #q11 FuncCall, q13 ArgList
        ('q11', 'var', 'FuncCall'): [('q13', '( ArgList )')],
        ('q13', '(', '('): [('q13', None)],
        ('q13', ')', ')'): [('q9', None)],
        ('q13', None, 'ArgList'): [('q9', 'Expr'), ('q9', 'Expr , ArgList')],

        #q8 Return
        ('q8', 'return', 'Return'): [('q9', 'Expr')],
    }


  def get_possible_transitions(self, symbol, top_of_stack):
    return self.transitions.get((self.state, symbol, top_of_stack))

  def push_to_stack(self, variables):
    if variables:
      for var in reversed(variables.split()):
          self.stack.append(var)

  def classify_token(self, token):
    if token in self.terminals:
      return token
    elif is_number(token):
      return 'num'
    else:
      return 'var'


  def process_input(self, tokens):
    # Recursive backtracking helper function
    def backtrack(index, step):
      if index == len(tokens):
        # If we've processed all tokens and stack is at the initial state, return True
        return self.stack[-1] == 'Z' and self.state == 'q0'

      token = tokens[index]
      print(f"Stack: {self.stack}, Input: {token}, State: {self.state}, Top: {self.stack[-1]}")


      top_of_stack = self.stack.pop()
      curr_state = self.state
      curr_stack = self.stack.copy()
      curr_path = self.path.copy()

      #Include as token, which can be a keyword, var, or num
      token_type = self.classify_token(token) #Returns token, num, or var
      possible_transitions = self.get_possible_transitions(token_type, top_of_stack)

      if possible_transitions:

        for next_state, variables in possible_transitions:
          print("possible: ", possible_transitions)
          print("Now Trying: ", variables)
          self.path.append((step, self.state, token, top_of_stack, next_state, variables))
          self.state = next_state

          self.push_to_stack(variables)

          if backtrack(index + 1, step + 1):
            return True

          self.state = curr_state
          self.stack = curr_stack.copy()
          self.path.pop()

      #Do not include token
      possible_transitions = self.get_possible_transitions(None, top_of_stack)
      if possible_transitions:

        for next_state, variables in possible_transitions:
          print("possible from None: ", possible_transitions)
          print("Now Trying From None: ", variables)
          self.path.append((step, self.state, 'None', top_of_stack, next_state, variables))
          self.state = next_state

          self.push_to_stack(variables)

          if backtrack(index, step + 1):
            return True

          self.state = curr_state
          self.stack = curr_stack.copy()
          self.path.pop()

      return False


    return backtrack(0, 0)

  def display_path(self):
    print("Transition Path:")
    for (step, current_state, input_symbol, stack_top, next_state, stack_op) in self.path:
        print(f"Step {step}: From state {current_state}, input '{input_symbol}', stack top '{stack_top}' -> "
              f"Next state {next_state}, stack push: '{stack_op}'")

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
def get_tokens(program):
  token_regex = r'\bint\b|\bfloat\b|\bvoid\b|\breturn\b|\b[a-zA-Z_]\w*\b|\d+[.]?\d*|[,{}();+=*]'
  tokens = re.findall(token_regex, program)
  return tokens


pda = PDA()
# program = """
# int f(int a) {
#   return a + 1;
# }

# int g(int b) {
#   return f(b) * 2;
# }

# int h(int c) {
#   return g(f(c));
# }

# int result = h(5);
# """

program = """
int f(int a) {
  return a + 1;
}

int g(int b) {
  return f(b) * 2;
}

int h(int c) {
  return g(f(c));
}

int result = h(5);
"""

tokens = get_tokens(program)

if pda.process_input(tokens):
  print("The program syntax is valid!")
  pda.display_path()
else:
  print("The program syntax is invalid!")
# Out:
# Stack: ['Z'], Input: int, State: q0, Top: Z
# possible from None:  [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')]
# Now Trying From None:  FuncDecl Z
# Stack: ['Z', 'FuncDecl'], Input: int, State: q1, Top: FuncDecl
# possible from None:  [('q1', 'ReturnType FunctionName ( ParamList ) Block')]
# Now Trying From None:  ReturnType FunctionName ( ParamList ) Block
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName', 'ReturnType'], Input: int, State: q1, Top: ReturnType
# possible:  [('q1', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName'], Input: f, State: q1, Top: FunctionName
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '('], Input: (, State: q3, Top: (
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList'], Input: int, State: q3, Top: ParamList
# possible from None:  [('q4', 'Param'), ('q4', 'Param , ParamList')]
# Now Trying From None:  Param
# Stack: ['Z', 'Block', ')', 'Param'], Input: int, State: q4, Top: Param
# possible:  [('q3', 'var')]
# Now Trying:  var
# Stack: ['Z', 'Block', ')', 'var'], Input: a, State: q3, Top: var
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')'], Input: ), State: q3, Top: )
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block'], Input: {, State: q3, Top: Block
# possible:  [('q5', 'StmtList }')]
# Now Trying:  StmtList }
# Stack: ['Z', '}', 'StmtList'], Input: return, State: q5, Top: StmtList
# possible from None:  [('q6', 'Stmt ;'), ('q6', 'Stmt ; StmtList')]
# Now Trying From None:  Stmt ;
# Stack: ['Z', '}', ';', 'Stmt'], Input: return, State: q6, Top: Stmt
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Assign
# Stack: ['Z', '}', ';', 'Assign'], Input: return, State: q7, Top: Assign
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Return
# Stack: ['Z', '}', ';', 'Return'], Input: return, State: q8, Top: Return
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: a, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: +, State: q6, Top: ;
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', 'Operator'], Input: +, State: q9, Top: Operator
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: 1, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: ;, State: q6, Top: ;
# possible:  [('q5', None)]
# Now Trying:  None
# Stack: ['Z', '}'], Input: }, State: q5, Top: }
# possible:  [('q0', None)]
# Now Trying:  None
# Stack: ['Z'], Input: int, State: q0, Top: Z
# possible from None:  [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')]
# Now Trying From None:  FuncDecl Z
# Stack: ['Z', 'FuncDecl'], Input: int, State: q1, Top: FuncDecl
# possible from None:  [('q1', 'ReturnType FunctionName ( ParamList ) Block')]
# Now Trying From None:  ReturnType FunctionName ( ParamList ) Block
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName', 'ReturnType'], Input: int, State: q1, Top: ReturnType
# possible:  [('q1', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName'], Input: g, State: q1, Top: FunctionName
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '('], Input: (, State: q3, Top: (
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList'], Input: int, State: q3, Top: ParamList
# possible from None:  [('q4', 'Param'), ('q4', 'Param , ParamList')]
# Now Trying From None:  Param
# Stack: ['Z', 'Block', ')', 'Param'], Input: int, State: q4, Top: Param
# possible:  [('q3', 'var')]
# Now Trying:  var
# Stack: ['Z', 'Block', ')', 'var'], Input: b, State: q3, Top: var
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')'], Input: ), State: q3, Top: )
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block'], Input: {, State: q3, Top: Block
# possible:  [('q5', 'StmtList }')]
# Now Trying:  StmtList }
# Stack: ['Z', '}', 'StmtList'], Input: return, State: q5, Top: StmtList
# possible from None:  [('q6', 'Stmt ;'), ('q6', 'Stmt ; StmtList')]
# Now Trying From None:  Stmt ;
# Stack: ['Z', '}', ';', 'Stmt'], Input: return, State: q6, Top: Stmt
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Assign
# Stack: ['Z', '}', ';', 'Assign'], Input: return, State: q7, Top: Assign
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Return
# Stack: ['Z', '}', ';', 'Return'], Input: return, State: q8, Top: Return
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: f, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: (, State: q6, Top: ;
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList'], Input: b, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', 'Expr'], Input: b, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: *, State: q6, Top: ;
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Expr'], Input: b, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', 'Operator', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')', 'ArgList'], Input: b, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', 'Operator', ')', 'Expr'], Input: b, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator'], Input: *, State: q6, Top: Operator
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: 2, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: ;, State: q6, Top: ;
# possible:  [('q5', None)]
# Now Trying:  None
# Stack: ['Z', '}'], Input: }, State: q5, Top: }
# possible:  [('q0', None)]
# Now Trying:  None
# Stack: ['Z'], Input: int, State: q0, Top: Z
# possible from None:  [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')]
# Now Trying From None:  FuncDecl Z
# Stack: ['Z', 'FuncDecl'], Input: int, State: q1, Top: FuncDecl
# possible from None:  [('q1', 'ReturnType FunctionName ( ParamList ) Block')]
# Now Trying From None:  ReturnType FunctionName ( ParamList ) Block
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName', 'ReturnType'], Input: int, State: q1, Top: ReturnType
# possible:  [('q1', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName'], Input: h, State: q1, Top: FunctionName
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '('], Input: (, State: q3, Top: (
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList'], Input: int, State: q3, Top: ParamList
# possible from None:  [('q4', 'Param'), ('q4', 'Param , ParamList')]
# Now Trying From None:  Param
# Stack: ['Z', 'Block', ')', 'Param'], Input: int, State: q4, Top: Param
# possible:  [('q3', 'var')]
# Now Trying:  var
# Stack: ['Z', 'Block', ')', 'var'], Input: c, State: q3, Top: var
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')'], Input: ), State: q3, Top: )
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block'], Input: {, State: q3, Top: Block
# possible:  [('q5', 'StmtList }')]
# Now Trying:  StmtList }
# Stack: ['Z', '}', 'StmtList'], Input: return, State: q5, Top: StmtList
# possible from None:  [('q6', 'Stmt ;'), ('q6', 'Stmt ; StmtList')]
# Now Trying From None:  Stmt ;
# Stack: ['Z', '}', ';', 'Stmt'], Input: return, State: q6, Top: Stmt
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Assign
# Stack: ['Z', '}', ';', 'Assign'], Input: return, State: q7, Top: Assign
# possible from None:  [('q7', 'Assign'), ('q8', 'Return')]
# Now Trying From None:  Return
# Stack: ['Z', '}', ';', 'Return'], Input: return, State: q8, Top: Return
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: g, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: (, State: q6, Top: ;
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList'], Input: f, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', 'Expr'], Input: f, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')'], Input: (, State: q6, Top: )
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', ')', 'ArgList'], Input: c, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', ')', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: +, State: q6, Top: ;
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', ')', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', ')', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', ')', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', ',', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', ',', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList'], Input: c, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'Operator', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'Operator'], Input: ), State: q6, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'Operator', ')', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', ',', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', ',', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'Operator', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Expr'], Input: f, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ','], Input: (, State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList'], Input: c, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', ',', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', ',', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList'], Input: c, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator'], Input: ), State: q6, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr , ArgList
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', ',', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', ','], Input: ), State: q6, Top: ,
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', ',', 'Operator'], Input: ), State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', ',', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', ',', 'Operator', ')', 'ArgList', '('], Input: ), State: q13, Top: (
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList ) Operator
# Stack: ['Z', '}', ';', 'Operator', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')', 'ArgList'], Input: f, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', 'Operator', ')', 'Expr'], Input: f, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')'], Input: (, State: q6, Top: )
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', '}', ';', 'Operator', ')', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', '}', ';', 'Operator', ')', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')', ')', 'ArgList'], Input: c, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', '}', ';', 'Operator', ')', ')', 'Expr'], Input: c, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z', '}', ';', 'Operator'], Input: +, State: q6, Top: Operator
# possible:  [('q9', 'Expr')]
# Now Trying:  Expr
# Stack: ['Z', '}', ';', 'Expr'], Input: 3, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator')]
# Now Trying:  None
# Stack: ['Z', '}', ';'], Input: ;, State: q6, Top: ;
# possible:  [('q5', None)]
# Now Trying:  None
# Stack: ['Z', '}'], Input: }, State: q5, Top: }
# possible:  [('q0', None)]
# Now Trying:  None
# Stack: ['Z'], Input: int, State: q0, Top: Z
# possible from None:  [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')]
# Now Trying From None:  FuncDecl Z
# Stack: ['Z', 'FuncDecl'], Input: int, State: q1, Top: FuncDecl
# possible from None:  [('q1', 'ReturnType FunctionName ( ParamList ) Block')]
# Now Trying From None:  ReturnType FunctionName ( ParamList ) Block
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName', 'ReturnType'], Input: int, State: q1, Top: ReturnType
# possible:  [('q1', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '(', 'FunctionName'], Input: result, State: q1, Top: FunctionName
# possible:  [('q3', None)]
# Now Trying:  None
# Stack: ['Z', 'Block', ')', 'ParamList', '('], Input: =, State: q3, Top: (
# possible from None:  [('q1', 'FuncDecl Z'), ('q2', 'Type Assign Z')]
# Now Trying From None:  Type Assign Z
# Stack: ['Z', 'Assign', 'Type'], Input: int, State: q2, Top: Type
# possible:  [('q7', None)]
# Now Trying:  None
# Stack: ['Z', 'Assign'], Input: result, State: q7, Top: Assign
# possible:  [('q9', '= Expr')]
# Now Trying:  = Expr
# Stack: ['Z', 'Expr', '='], Input: =, State: q9, Top: =
# possible:  [('q9', None)]
# Now Trying:  None
# Stack: ['Z', 'Expr'], Input: h, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  None
# Stack: ['Z'], Input: (, State: q6, Top: Z
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  Operator
# Stack: ['Z', 'Operator'], Input: (, State: q9, Top: Operator
# possible:  [('q6', None), ('q9', 'Operator'), ('q13', '( ArgList )'), ('q13', '( ArgList ) Operator')]
# Now Trying:  ( ArgList )
# Stack: ['Z', ')', 'ArgList', '('], Input: (, State: q13, Top: (
# possible:  [('q13', None)]
# Now Trying:  None
# Stack: ['Z', ')', 'ArgList'], Input: 5, State: q13, Top: ArgList
# possible from None:  [('q9', 'Expr'), ('q9', 'Expr , ArgList')]
# Now Trying From None:  Expr
# Stack: ['Z', ')', 'Expr'], Input: 5, State: q9, Top: Expr
# possible:  [('q6', None), ('q9', 'Operator')]
# Now Trying:  None
# Stack: ['Z', ')'], Input: ), State: q6, Top: )
# possible:  [('q6', None)]
# Now Trying:  None
# Stack: ['Z'], Input: ;, State: q6, Top: Z
# possible:  [('q0', 'Z')]
# Now Trying:  Z
# The program syntax is valid!
# Transition Path:
# Step 0: From state q0, input 'None', stack top 'Z' -> Next state q1, stack push: 'FuncDecl Z'
# Step 1: From state q1, input 'None', stack top 'FuncDecl' -> Next state q1, stack push: 'ReturnType FunctionName ( ParamList ) Block'
# Step 2: From state q1, input 'int', stack top 'ReturnType' -> Next state q1, stack push: 'None'
# Step 3: From state q1, input 'f', stack top 'FunctionName' -> Next state q3, stack push: 'None'
# Step 4: From state q3, input '(', stack top '(' -> Next state q3, stack push: 'None'
# Step 5: From state q3, input 'None', stack top 'ParamList' -> Next state q4, stack push: 'Param'
# Step 6: From state q4, input 'int', stack top 'Param' -> Next state q3, stack push: 'var'
# Step 7: From state q3, input 'a', stack top 'var' -> Next state q3, stack push: 'None'
# Step 8: From state q3, input ')', stack top ')' -> Next state q3, stack push: 'None'
# Step 9: From state q3, input '{', stack top 'Block' -> Next state q5, stack push: 'StmtList }'
# Step 10: From state q5, input 'None', stack top 'StmtList' -> Next state q6, stack push: 'Stmt ;'
# Step 11: From state q6, input 'None', stack top 'Stmt' -> Next state q8, stack push: 'Return'
# Step 12: From state q8, input 'return', stack top 'Return' -> Next state q9, stack push: 'Expr'
# Step 13: From state q9, input 'a', stack top 'Expr' -> Next state q9, stack push: 'Operator'
# Step 14: From state q9, input '+', stack top 'Operator' -> Next state q9, stack push: 'Expr'
# Step 15: From state q9, input '1', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 16: From state q6, input ';', stack top ';' -> Next state q5, stack push: 'None'
# Step 17: From state q5, input '}', stack top '}' -> Next state q0, stack push: 'None'
# Step 18: From state q0, input 'None', stack top 'Z' -> Next state q1, stack push: 'FuncDecl Z'
# Step 19: From state q1, input 'None', stack top 'FuncDecl' -> Next state q1, stack push: 'ReturnType FunctionName ( ParamList ) Block'
# Step 20: From state q1, input 'int', stack top 'ReturnType' -> Next state q1, stack push: 'None'
# Step 21: From state q1, input 'g', stack top 'FunctionName' -> Next state q3, stack push: 'None'
# Step 22: From state q3, input '(', stack top '(' -> Next state q3, stack push: 'None'
# Step 23: From state q3, input 'None', stack top 'ParamList' -> Next state q4, stack push: 'Param'
# Step 24: From state q4, input 'int', stack top 'Param' -> Next state q3, stack push: 'var'
# Step 25: From state q3, input 'b', stack top 'var' -> Next state q3, stack push: 'None'
# Step 26: From state q3, input ')', stack top ')' -> Next state q3, stack push: 'None'
# Step 27: From state q3, input '{', stack top 'Block' -> Next state q5, stack push: 'StmtList }'
# Step 28: From state q5, input 'None', stack top 'StmtList' -> Next state q6, stack push: 'Stmt ;'
# Step 29: From state q6, input 'None', stack top 'Stmt' -> Next state q8, stack push: 'Return'
# Step 30: From state q8, input 'return', stack top 'Return' -> Next state q9, stack push: 'Expr'
# Step 31: From state q9, input 'f', stack top 'Expr' -> Next state q13, stack push: '( ArgList ) Operator'
# Step 32: From state q13, input '(', stack top '(' -> Next state q13, stack push: 'None'
# Step 33: From state q13, input 'None', stack top 'ArgList' -> Next state q9, stack push: 'Expr'
# Step 34: From state q9, input 'b', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 35: From state q6, input ')', stack top ')' -> Next state q6, stack push: 'None'
# Step 36: From state q6, input '*', stack top 'Operator' -> Next state q9, stack push: 'Expr'
# Step 37: From state q9, input '2', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 38: From state q6, input ';', stack top ';' -> Next state q5, stack push: 'None'
# Step 39: From state q5, input '}', stack top '}' -> Next state q0, stack push: 'None'
# Step 40: From state q0, input 'None', stack top 'Z' -> Next state q1, stack push: 'FuncDecl Z'
# Step 41: From state q1, input 'None', stack top 'FuncDecl' -> Next state q1, stack push: 'ReturnType FunctionName ( ParamList ) Block'
# Step 42: From state q1, input 'int', stack top 'ReturnType' -> Next state q1, stack push: 'None'
# Step 43: From state q1, input 'h', stack top 'FunctionName' -> Next state q3, stack push: 'None'
# Step 44: From state q3, input '(', stack top '(' -> Next state q3, stack push: 'None'
# Step 45: From state q3, input 'None', stack top 'ParamList' -> Next state q4, stack push: 'Param'
# Step 46: From state q4, input 'int', stack top 'Param' -> Next state q3, stack push: 'var'
# Step 47: From state q3, input 'c', stack top 'var' -> Next state q3, stack push: 'None'
# Step 48: From state q3, input ')', stack top ')' -> Next state q3, stack push: 'None'
# Step 49: From state q3, input '{', stack top 'Block' -> Next state q5, stack push: 'StmtList }'
# Step 50: From state q5, input 'None', stack top 'StmtList' -> Next state q6, stack push: 'Stmt ;'
# Step 51: From state q6, input 'None', stack top 'Stmt' -> Next state q8, stack push: 'Return'
# Step 52: From state q8, input 'return', stack top 'Return' -> Next state q9, stack push: 'Expr'
# Step 53: From state q9, input 'g', stack top 'Expr' -> Next state q13, stack push: '( ArgList ) Operator'
# Step 54: From state q13, input '(', stack top '(' -> Next state q13, stack push: 'None'
# Step 55: From state q13, input 'None', stack top 'ArgList' -> Next state q9, stack push: 'Expr'
# Step 56: From state q9, input 'f', stack top 'Expr' -> Next state q13, stack push: '( ArgList )'
# Step 57: From state q13, input '(', stack top '(' -> Next state q13, stack push: 'None'
# Step 58: From state q13, input 'None', stack top 'ArgList' -> Next state q9, stack push: 'Expr'
# Step 59: From state q9, input 'c', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 60: From state q6, input ')', stack top ')' -> Next state q6, stack push: 'None'
# Step 61: From state q6, input ')', stack top ')' -> Next state q6, stack push: 'None'
# Step 62: From state q6, input '+', stack top 'Operator' -> Next state q9, stack push: 'Expr'
# Step 63: From state q9, input '3', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 64: From state q6, input ';', stack top ';' -> Next state q5, stack push: 'None'
# Step 65: From state q5, input '}', stack top '}' -> Next state q0, stack push: 'None'
# Step 66: From state q0, input 'None', stack top 'Z' -> Next state q2, stack push: 'Type Assign Z'
# Step 67: From state q2, input 'int', stack top 'Type' -> Next state q7, stack push: 'None'
# Step 68: From state q7, input 'result', stack top 'Assign' -> Next state q9, stack push: '= Expr'
# Step 69: From state q9, input '=', stack top '=' -> Next state q9, stack push: 'None'
# Step 70: From state q9, input 'h', stack top 'Expr' -> Next state q13, stack push: '( ArgList )'
# Step 71: From state q13, input '(', stack top '(' -> Next state q13, stack push: 'None'
# Step 72: From state q13, input 'None', stack top 'ArgList' -> Next state q9, stack push: 'Expr'
# Step 73: From state q9, input '5', stack top 'Expr' -> Next state q6, stack push: 'None'
# Step 74: From state q6, input ')', stack top ')' -> Next state q6, stack push: 'None'
# Step 75: From state q6, input ';', stack top 'Z' -> Next state q0, stack push: 'Z'
